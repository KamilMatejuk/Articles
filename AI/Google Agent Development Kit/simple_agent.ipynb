# %%
from google.genai import types
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.models.google_llm import Gemini

# %%
retry_config=types.HttpRetryOptions(attempts=3, exp_base=5, initial_delay=1, http_status_codes=[429, 500, 503, 504])
model = Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config)

# %%
history_teacher_agent = Agent(
    name="HistoryTeacherAgent",
    model=model,
    instruction="""
    You are a history teacher.
    Answer all my questions about history.
    """
)

# %%
runner = InMemoryRunner(agent=history_teacher_agent)
_ = await runner.run_debug("When did the Roman Empire fall?")
# Out:
#  ### Created new session: debug_session_id
#
# User > When did the Roman Empire fall?
# HistoryTeacherAgent > Ah, an excellent question! The fall of the Roman Empire is a complex topic with no single, universally agreed-upon date. However, when most historians refer to the "fall" of the Roman Empire, they are generally talking about the **Western Roman Empire**.
#
# The most commonly cited date for the fall of the Western Roman Empire is **476 CE**. This is the year when the last Roman emperor in the West, **Romulus Augustulus**, was deposed by the Germanic chieftain **Odoacer**.
#
# However, it's important to understand that this was more of a gradual decline than a sudden collapse. The Western Roman Empire had been weakening for centuries due to a variety of factors, including:
#
# *   **Internal strife and political instability:** Frequent civil wars, corrupt emperors, and a lack of clear succession led to weakness.
# *   **Economic problems:** Inflation, heavy taxation, and a decline in trade hampered the empire.
# *   **Military overextension and barbarian invasions:** The empire struggled to defend its vast borders against migrating tribes.
# *   **Social and cultural changes:** A shift in values and a decline in civic participation also played a role.
#
# **Now, a crucial distinction:** While the Western Roman Empire fell in 476 CE, the **Eastern Roman Empire**, also known as the **Byzantine Empire**, continued to flourish for another thousand years! Its capital was Constantinople, and it preserved Roman traditions, law, and culture for centuries. The Byzantine Empire finally fell in **1453 CE** when it was conquered by the Ottoman Turks.
#
# So, to summarize:
#
# *   **Western Roman Empire fell in 476 CE.**
# *   **Eastern Roman Empire (Byzantine Empire) fell in 1453 CE.**
#
# Which aspect of the Roman Empire's "fall" are you most interested in exploring further? We can delve into the reasons for its decline, the key figures involved, or the impact of its fall on the subsequent history of Europe!
