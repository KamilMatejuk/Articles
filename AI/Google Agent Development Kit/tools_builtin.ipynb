# %%
from google.genai import types
from google.adk.agents import Agent
from google.adk.tools import google_search
from google.adk.runners import InMemoryRunner
from google.adk.models.google_llm import Gemini

# %%
retry_config=types.HttpRetryOptions(attempts=3, exp_base=5, initial_delay=1, http_status_codes=[429, 500, 503, 504])
model = Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config)

# %%
history_teacher_agent = Agent(
    name="HistoryTeacherAgent",
    model=model,
    instruction="""
    You are a history teacher.
    Answer all my questions about history.
    If you are not sure, use google_search tool.
    """,
    tools=[google_search],
)

# %%
runner = InMemoryRunner(agent=history_teacher_agent)
_ = await runner.run_debug("How many times was Donald Trump elected president?")
# Out:
#  ### Created new session: debug_session_id
#
# User > How many times was Donald Trump elected president?
# HistoryTeacherAgent > Donald Trump has been elected president of the United States two times. He served as the 45th president from 2017 to 2021 and was inaugurated for his second, non-consecutive term as the 47th president on January 20, 2025. He was elected in 2016 and again in 2024. He lost the 2020 presidential election to Joe Biden.
