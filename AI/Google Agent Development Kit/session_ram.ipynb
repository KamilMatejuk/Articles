# %%
from google.genai import types
from google.adk.agents import Agent
from google.adk.runners import Runner
from google.adk.models.google_llm import Gemini
from google.adk.sessions import InMemorySessionService

# %%
retry_config=types.HttpRetryOptions(attempts=3, exp_base=5, initial_delay=1, http_status_codes=[429, 500, 503, 504])
model = Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config)

# %%
assistant_agent = Agent(
    name="AssistantAgent",
    model=model,
    instruction="You are a personal assistant",
)

# %%
session_service = InMemorySessionService()

# %%
runner = Runner(agent=assistant_agent, app_name="Runner", session_service=session_service)

# %%
_ = await runner.run_debug("I love eating ice cream. What are some other desserts I might like?")
# Out:
#  ### Created new session: debug_session_id
#
# User > I love eating ice cream. What are some other desserts I might like?
# AssistantAgent > That's great! Since you love ice cream, you probably enjoy desserts that are:
#
# *   **Sweet:** Obviously!
# *   **Cold or Creamy:** Ice cream's texture is a big part of its appeal.
# *   **Rich and Indulgent:** Often, ice cream is a treat for special occasions or when you want something decadent.
# *   **Versatile:** Ice cream comes in so many flavors and can be enjoyed on its own or with toppings.
#
# Based on those preferences, here are some other desserts you might really enjoy:
#
# **For the Creamy & Cold Lover:**
#
# *   **Gelato:** Very similar to ice cream but typically denser, richer, and made with less cream and more milk. It's churned at a slower speed, resulting in a smoother texture and more intense flavor.
# *   **Sorbet/Sherbet:** If you like the cold, refreshing aspect of ice cream but maybe want something a little lighter or fruitier, sorbet (fruit and sugar, no dairy) or sherbet (fruit, sugar, and a little dairy) are excellent choices.
# *   **Frozen Yogurt (Fro-Yo):** A classic alternative to ice cream, often perceived as healthier but still offering that cold, creamy indulgence. The tanginess of the yogurt can be a nice contrast.
# *   **Mousse:** Light, airy, and rich, mousse can be made with chocolate, fruit, or other flavors. It's chilled, offering a lovely creamy texture that melts in your mouth.
# *   **Puddings and Custards:** Think creamy, smooth, and often served chilled. Crème brûlée, panna cotta, chocolate pudding, or rice pudding can be incredibly satisfying.
#
# **For the Rich & Indulgent Lover:**
#
# *   **Cheesecake:** Creamy, dense, and rich, cheesecake is a fantastic option. It can be flavored in countless ways, from classic New York style to chocolate, fruit, or even salted caramel.
# *   **Tiramisu:** This Italian dessert features layers of coffee-soaked ladyfingers, mascarpone cheese, eggs, sugar, and cocoa. It's rich, creamy, and has a wonderful coffee kick.
# *   **Brownies/Blondies:** Dense, fudgy, and incredibly satisfying. They offer a chewy or cakey texture and a rich chocolate (or other flavor) hit.
# *   **Molten Chocolate Lava Cakes:** Warm, gooey chocolate cake with a molten chocolate center that oozes out when you cut into it. Often served with ice cream or whipped cream!
# *   **Pecan Pie/Nut Pies:** These often have a rich, gooey filling that's incredibly decadent.
#
# **For the Flavor Explorer:**
#
# *   **Anything with Fruit Combinations:** Since you like ice cream, you probably enjoy sweet and sometimes tart flavors. Look for desserts that highlight fruits, like:
#     *   **Fruit Tarts:** Beautiful and delicious, with flaky crusts and fresh fruit fillings.
#     *   **Fruit Cobblers/Crumbles:** Warm, baked fruit topped with a sweet, crumbly topping. Often served with ice cream!
#     *   **Key Lime Pie:** Tart, creamy, and refreshing.
#     *   **Lemon Meringue Pie:** A tangy lemon filling with a sweet, fluffy meringue topping.
#
# **To help me narrow it down even more, tell me:**
#
# *   What are your *favorite* ice cream flavors?
# *   Do you prefer something very sweet, or do you like a little tang or bitterness (like dark chocolate or coffee)?
# *   Are you looking for something you can make at home, or are you looking for recommendations for bakeries/restaurants?
#
# Happy dessert hunting!

# %%
_ = await runner.run_debug("What do you know about my dessert preferences?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What do you know about my dessert preferences?
# AssistantAgent > Based on your initial statement, "I love eating ice cream," I can infer the following about your dessert preferences:
#
# *   **You enjoy sweetness:** This is the most obvious characteristic of ice cream.
# *   **You likely enjoy creamy textures:** The smooth, rich, and often cold texture of ice cream is a primary appeal for many.
# *   **You appreciate indulgence:** Ice cream is often seen as a treat, something enjoyable and perhaps a bit decadent.
# *   **You might like cold desserts:** The frozen aspect is fundamental to ice cream.
# *   **You probably enjoy a variety of flavors:** Ice cream comes in countless flavors, and people who love it often appreciate exploring different taste profiles.
#
# These are educated guesses, of course! If you want to tell me more about what you like or dislike about ice cream, I can give you even more tailored recommendations.
