# %%
from google.genai import types
from google.adk.runners import InMemoryRunner
from google.adk.models.google_llm import Gemini
from google.adk.agents import Agent, SequentialAgent

# %%
retry_config=types.HttpRetryOptions(attempts=3, exp_base=5, initial_delay=1, http_status_codes=[429, 500, 503, 504])
model = Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config)

# %%
idea_agent = Agent(
    name="IdeaAgent",
    model=model,
    instruction="""
    You are a creative idea generator for short videos for social media.
    Create unique and innovative idea based on user prompts.
    Return only one idea, concise and engaging, in a single sentence.
    """,
    output_key="idea"
)

# %%
script_agent = Agent(
    name="ScriptAgent",
    model=model,
    instruction="""
    You are a video script generator for short videos for social media.
    Based on the provided idea, create an engaging and concise script suitable for a short video format.
    Idea: {idea}
    """,
)

# %%
orchiestrator_agent = SequentialAgent(
    name="SequentialPipeline",
    sub_agents=[idea_agent, script_agent],
)

# %%
runner = InMemoryRunner(agent=orchiestrator_agent)
_ = await runner.run_debug("Create a short video about AI in healthcare.")
# Out:
#  ### Created new session: debug_session_id
#
# User > Create a short video about AI in healthcare.
# IdeaAgent > Show a split screen: one side features a doctor meticulously examining an X-ray, the other side shows an AI rapidly analyzing the same scan, highlighting potential diagnoses with uncanny accuracy and speed.
# ScriptAgent > Okay, ScriptAgent here! I've got a script that should work perfectly for that split-screen concept.
#
# **Video Title Suggestion:** AI vs. The X-Ray: A New Era in Diagnosis
#
# **Video Length:** Approximately 30-45 seconds
#
# **Visuals:** Split Screen throughout.
#
# **(0-3 seconds)**
# *   **Visual:** Split screen.
#     *   **LEFT:** Close-up on a doctor's face, looking intently at a glowing X-ray on a lightbox. Their brow is furrowed slightly in concentration.
#     *   **RIGHT:** A sleek, abstract digital interface. Lines of code or data streams rapidly scroll across a screen. A digital representation of the *same* X-ray appears.
# *   **Audio:** Subtle, building ambient electronic music.
#
# **(3-10 seconds)**
# *   **Visual:**
#     *   **LEFT:** The doctor slowly points a pen or finger at a specific area on the X-ray, maybe leaning closer.
#     *   **RIGHT:** The AI interface highlights multiple areas on the X-ray with glowing red circles or bounding boxes. Text overlays appear rapidly: "Potential Lesion Detected," "Anomalous Growth Probability: 88%," "Suggesting Further Imaging."
# *   **Audio:** Music becomes more pronounced, with a subtle "ping" or "scan" sound effect as the AI highlights areas.
#
# **(10-18 seconds)**
# *   **Visual:**
#     *   **LEFT:** The doctor is now looking slightly surprised, perhaps pulling up patient notes on a tablet, comparing them to the X-ray.
#     *   **RIGHT:** The AI interface shows a concise summary of potential diagnoses, ranked by probability. A progress bar quickly fills, showing "Analysis Complete."
# *   **Audio:** A soft, intelligent "ding" sound. Music shifts to a more optimistic, forward-thinking tone.
#
# **(18-25 seconds)**
# *   **Visual:**
#     *   **LEFT:** The doctor nods, a look of understanding or confirmation on their face. They might tap their tablet or make a note.
#     *   **RIGHT:** The AI interface presents a clear, synthesized overview: "AI-Assisted Diagnosis: Highly Probable Condition X. Early Detection Enhanced."
# *   **Audio:** Music swells slightly. A calm, reassuring voiceover begins.
#
# **(25-35 seconds)**
# *   **Visual:**
#     *   **LEFT:** The doctor looks up from the X-ray, directly at the camera with a confident, appreciative expression.
#     *   **RIGHT:** The AI interface fades slightly, replaced by a clean graphic: "AI in Healthcare: Precision. Speed. Aiding Experts."
# *   **Audio:**
#     *   **Voiceover:** "AI isn't replacing doctors. It's empowering them. Delivering faster, more accurate insights when it matters most."
#     *   **Music:** Continues to be inspiring and positive.
#
# **(35-40 seconds)**
# *   **Visual:** Full screen graphic with call to action.
#     *   Text: "The Future of Medicine is Here."
#     *   Optional: Logo of the organization/company presenting this.
#     *   Optional: Social media handles.
# *   **Audio:** Music fades out with a final, resonant chord.
#
# ---
#
# **Key Elements to Emphasize:**
#
# *   **Speed:** The rapid flashing and highlighting on the AI side.
# *   **Accuracy:** The precise identification of potential issues.
# *   **Collaboration:** The doctor's thoughtful reaction, showing AI as a tool, not a replacement.
# *   **Clarity:** Simple, impactful text overlays.
#
# Let me know what you think or if you'd like any adjustments!
